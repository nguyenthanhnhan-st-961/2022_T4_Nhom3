# %%
import pandas as pd
from datetime import datetime, date, time

# %%
data = pd.read_csv('D:\VSCode\DataWarehouse\extracted_data.csv')
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 data = pd.read_csv('D:\VSCode\DataWarehouse\extracted_data.csv')
#       2 data.head()
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ### Transform "Date"

# %%
data['Date']=data['Date'].transform(lambda x: datetime.strptime(x, '%d/%m/%Y').date())
data.head()
# Out:
#           Name        Date   Time Temperature        Description Low/high  \
# 0     Hà Giang  2022-09-11  09:15         28°          Nhiều mây  21°/31°
# 1     Cao Bằng  2022-09-11  09:15         23°            Mưa nhẹ  21°/28°
# 2      Bắc Kạn  2022-09-11  09:15         26°            Mưa nhẹ  22°/29°
# 3  Tuyên Quang  2022-09-11  09:15         26°            Mây cụm  22°/29°
# 4  Thái Nguyên  2022-09-11  09:15         28°  Mưa cường độ nặng  23°/32°
#
#   Humidity   Vision         Wind  UV index Air quality
# 0      72%    10 km  0.41 km/giờ      4.58         Tốt
# 1      97%    10 km  0.88 km/giờ      2.46         Tốt
# 2      94%  6.36 km  0.06 km/giờ      4.68         Tốt
# 3      89%    10 km  0.44 km/giờ      4.78         Khá
# 4      83%    10 km  0.37 km/giờ      4.80         Kém

# %% [markdown]
# ### Transform "Time"

# %%
data['Time']=data["Time"].transform(lambda x: datetime.strptime(x, '%H:%M').time())
data.head()
# Out:
#           Name        Date      Time Temperature        Description Low/high  \
# 0     Hà Giang  2022-09-11  09:15:00         28°          Nhiều mây  21°/31°
# 1     Cao Bằng  2022-09-11  09:15:00         23°            Mưa nhẹ  21°/28°
# 2      Bắc Kạn  2022-09-11  09:15:00         26°            Mưa nhẹ  22°/29°
# 3  Tuyên Quang  2022-09-11  09:15:00         26°            Mây cụm  22°/29°
# 4  Thái Nguyên  2022-09-11  09:15:00         28°  Mưa cường độ nặng  23°/32°
#
#   Humidity   Vision         Wind  UV index Air quality
# 0      72%    10 km  0.41 km/giờ      4.58         Tốt
# 1      97%    10 km  0.88 km/giờ      2.46         Tốt
# 2      94%  6.36 km  0.06 km/giờ      4.68         Tốt
# 3      89%    10 km  0.44 km/giờ      4.78         Khá
# 4      83%    10 km  0.37 km/giờ      4.80         Kém

# %% [markdown]
# ### Transform "Temperature"

# %%
data['Temperature']=data['Temperature'].transform(lambda x : int(x.replace('°', '')))
data.head()
# Out:
#           Name        Date      Time  Temperature        Description Low/high  \
# 0     Hà Giang  2022-09-11  09:15:00           28          Nhiều mây  21°/31°
# 1     Cao Bằng  2022-09-11  09:15:00           23            Mưa nhẹ  21°/28°
# 2      Bắc Kạn  2022-09-11  09:15:00           26            Mưa nhẹ  22°/29°
# 3  Tuyên Quang  2022-09-11  09:15:00           26            Mây cụm  22°/29°
# 4  Thái Nguyên  2022-09-11  09:15:00           28  Mưa cường độ nặng  23°/32°
#
#   Humidity   Vision         Wind  UV index Air quality
# 0      72%    10 km  0.41 km/giờ      4.58         Tốt
# 1      97%    10 km  0.88 km/giờ      2.46         Tốt
# 2      94%  6.36 km  0.06 km/giờ      4.68         Tốt
# 3      89%    10 km  0.44 km/giờ      4.78         Khá
# 4      83%    10 km  0.37 km/giờ      4.80         Kém

# %% [markdown]
# ### Transform "Low/high"

# %%
data['Low/high']=data['Low/high'].transform(lambda x : x.replace('°', ''))
data.head()
# Out:
#           Name        Date      Time  Temperature        Description Low/high  \
# 0     Hà Giang  2022-09-11  09:15:00           28          Nhiều mây    21/31
# 1     Cao Bằng  2022-09-11  09:15:00           23            Mưa nhẹ    21/28
# 2      Bắc Kạn  2022-09-11  09:15:00           26            Mưa nhẹ    22/29
# 3  Tuyên Quang  2022-09-11  09:15:00           26            Mây cụm    22/29
# 4  Thái Nguyên  2022-09-11  09:15:00           28  Mưa cường độ nặng    23/32
#
#   Humidity   Vision         Wind  UV index Air quality
# 0      72%    10 km  0.41 km/giờ      4.58         Tốt
# 1      97%    10 km  0.88 km/giờ      2.46         Tốt
# 2      94%  6.36 km  0.06 km/giờ      4.68         Tốt
# 3      89%    10 km  0.44 km/giờ      4.78         Khá
# 4      83%    10 km  0.37 km/giờ      4.80         Kém

# %% [markdown]
# ### Transform "Humidity"

# %%
data['Humidity']=data['Humidity'].transform(lambda x : int(x.replace('%', '')))
data.head()
# Out:
#           Name        Date      Time  Temperature        Description Low/high  \
# 0     Hà Giang  2022-09-11  09:15:00           28          Nhiều mây    21/31
# 1     Cao Bằng  2022-09-11  09:15:00           23            Mưa nhẹ    21/28
# 2      Bắc Kạn  2022-09-11  09:15:00           26            Mưa nhẹ    22/29
# 3  Tuyên Quang  2022-09-11  09:15:00           26            Mây cụm    22/29
# 4  Thái Nguyên  2022-09-11  09:15:00           28  Mưa cường độ nặng    23/32
#
#    Humidity   Vision         Wind  UV index Air quality
# 0        72    10 km  0.41 km/giờ      4.58         Tốt
# 1        97    10 km  0.88 km/giờ      2.46         Tốt
# 2        94  6.36 km  0.06 km/giờ      4.68         Tốt
# 3        89    10 km  0.44 km/giờ      4.78         Khá
# 4        83    10 km  0.37 km/giờ      4.80         Kém

# %% [markdown]
# ### Transform "Vision"

# %%
data['Vision']=data['Vision'].transform(lambda x : float(x.split(" ")[0])) 
data.head()
# Out:
#           Name        Date      Time  Temperature        Description Low/high  \
# 0     Hà Giang  2022-09-11  09:15:00           28          Nhiều mây    21/31
# 1     Cao Bằng  2022-09-11  09:15:00           23            Mưa nhẹ    21/28
# 2      Bắc Kạn  2022-09-11  09:15:00           26            Mưa nhẹ    22/29
# 3  Tuyên Quang  2022-09-11  09:15:00           26            Mây cụm    22/29
# 4  Thái Nguyên  2022-09-11  09:15:00           28  Mưa cường độ nặng    23/32
#
#    Humidity  Vision         Wind  UV index Air quality
# 0        72   10.00  0.41 km/giờ      4.58         Tốt
# 1        97   10.00  0.88 km/giờ      2.46         Tốt
# 2        94    6.36  0.06 km/giờ      4.68         Tốt
# 3        89   10.00  0.44 km/giờ      4.78         Khá
# 4        83   10.00  0.37 km/giờ      4.80         Kém

# %% [markdown]
# ### Transfom "Wind"

# %%
data['Wind']=data['Wind'].transform(lambda x : float(x.split(" ")[0])) 
data.head()
# Out:
#           Name        Date      Time  Temperature        Description Low/high  \
# 0     Hà Giang  2022-09-11  09:15:00           28          Nhiều mây    21/31
# 1     Cao Bằng  2022-09-11  09:15:00           23            Mưa nhẹ    21/28
# 2      Bắc Kạn  2022-09-11  09:15:00           26            Mưa nhẹ    22/29
# 3  Tuyên Quang  2022-09-11  09:15:00           26            Mây cụm    22/29
# 4  Thái Nguyên  2022-09-11  09:15:00           28  Mưa cường độ nặng    23/32
#
#    Humidity  Vision  Wind  UV index Air quality
# 0        72   10.00  0.41      4.58         Tốt
# 1        97   10.00  0.88      2.46         Tốt
# 2        94    6.36  0.06      4.68         Tốt
# 3        89   10.00  0.44      4.78         Khá
# 4        83   10.00  0.37      4.80         Kém

# %%
print('°')
# Out:
# °

# %%
data
# Out:
#             Name        Date      Time  Temperature        Description  \
# 0       Hà Giang  2022-09-11  09:15:00           28          Nhiều mây
# 1       Cao Bằng  2022-09-11  09:15:00           23            Mưa nhẹ
# 2        Bắc Kạn  2022-09-11  09:15:00           26            Mưa nhẹ
# 3    Tuyên Quang  2022-09-11  09:15:00           26            Mây cụm
# 4    Thái Nguyên  2022-09-11  09:15:00           28  Mưa cường độ nặng
# ..           ...         ...       ...          ...                ...
# 688      Cần Thơ  2022-09-11  20:15:00           23            Mây cụm
# 689    Hậu Giang  2022-09-11  20:15:00           24          Nhiều mây
# 690    Sóc Trăng  2022-09-11  20:15:00           25          Nhiều mây
# 691     Bạc Liêu  2022-09-11  20:15:00           25          Nhiều mây
# 692       Cà Mau  2022-09-11  20:15:00           24          Nhiều mây
#
#     Low/high  Humidity  Vision  Wind  UV index Air quality
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693 entries, 0 to 692
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         693 non-null    object
#  1   Date         693 non-null    object
#  2   Time         693 non-null    object
#  3   Temperature  693 non-null    int64
#  4   Description  693 non-null    object
#  5   Low/high     693 non-null    object
#  6   Humidity     693 non-null    int64
#  7   Vision       693 non-null    float64
#  8   Wind         693 non-null    float64
#  9   UV index     693 non-null    float64
#  10  Air quality  693 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 59.7+ KB

# %%
import ftplib
server = ftplib.FTP('103.97.126.30','nhan123@demoxii.tk','123456')
server.encoding = 'utf-8'
server.cwd('/DW/3-10')
print(server.dir())
# Out:
# drwxr-xr-x    2 9140       jzcmffxz         4096 Oct  3 19:03 .
# drwxr-xr-x    5 9140       jzcmffxz         4096 Oct  3 19:02 ..
# -rw-r--r--    1 9140       jzcmffxz        60121 Oct  3 19:03 edu_data-3_10.csv
# None

# %%
#upload file to server
filename='etl_data.csv'
with open(filename, 'rb') as file:
    server.storbinary(f"STOR {filename}", file)
print(server.dir())
server.quit()
# Out:
# drwxr-xr-x    2 9140       jzcmffxz         4096 Sep 28 13:56 .
# drwxr-xr-x    4 9140       jzcmffxz         4096 Sep 28 13:42 ..
# -rw-r--r--    1 9140       jzcmffxz         4638 Sep 28 13:56 etl_data.csv
# -rw-r--r--    1 9140       jzcmffxz        46183 Sep 27 18:03 hcvdat.csv
# None
# '221-Goodbye. You uploaded 5 and downloaded 0 kbytes.\n221 Logout.'

# %%
#down load file from FTP
filename='edu_data-3_10.csv'
with open(filename, 'wb') as file:
    server.retrbinary(f"RETR {filename}", file.write)
print(server.dir())
server.quit()
with open(filename, 'r') as file:
    print(file.read())
# Out:
# drwxr-xr-x    2 9140       jzcmffxz         4096 Oct  3 19:03 .
# drwxr-xr-x    5 9140       jzcmffxz         4096 Oct  3 19:02 ..
# -rw-r--r--    1 9140       jzcmffxz        60121 Oct  3 19:03 edu_data-3_10.csv
# None
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# d:\VSCode\DataWarehouse\test.ipynb Cell 24 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/d%3A/VSCode/DataWarehouse/test.ipynb#X32sZmlsZQ%3D%3D?line=5'>6</a> server.quit()
#       <a href='vscode-notebook-cell:/d%3A/VSCode/DataWarehouse/test.ipynb#X32sZmlsZQ%3D%3D?line=6'>7</a> with open(filename, 'r') as file:
# ----> <a href='vscode-notebook-cell:/d%3A/VSCode/DataWarehouse/test.ipynb#X32sZmlsZQ%3D%3D?line=7'>8</a>     print(file.read())
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python310\lib\encodings\cp1258.py:23, in IncrementalDecoder.decode(self, input, final)
# ...

# %%
import csv
with open('etl_data.csv', 'r', encoding='utf-8') as csvfile:
        csv_data=csv.reader(csvfile)
        for row in csv_data:
            print(type(row))

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

url='https://thoitiet.vn/'
html=requests.get(url)

bs=BeautifulSoup(html.text,'html.parser')
a=bs.find_all('a',title=True)

provinces={}
for i in a[:-2]:
    provinces[str(i.attrs['href']).replace('/','')]=str(i.attrs['title']).strip()

# for province in provinces:
url=url+list(provinces.keys())[0]
content=requests.get(url)
soup=BeautifulSoup(content.text,'html.parser')
weather_detail = soup.find_all('span', class_='text-white op-8 fw-bold')
air=str(soup.find('h2',class_='air-title').string).strip()
print(air)
# Out:
# Chất lượng không khí: Kém
